# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
dataset= pd.read_csv("C:\\Users\\Asus\\OneDrive\\Desktop\\python\\Machine learming\\PROJECT_3\\day.csv")
dataset
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  01-01-2018       1   0     1        0        6           0
# 1          2  02-01-2018       1   0     1        0        0           0
# 2          3  03-01-2018       1   0     1        0        1           1
# 3          4  04-01-2018       1   0     1        0        2           1
# 4          5  05-01-2018       1   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 725      726  27-12-2019       1   1    12        0        4           1
# 726      727  28-12-2019       1   1    12        0        5           1
# 727      728  29-12-2019       1   1    12        0        6           0
# 728      729  30-12-2019       1   1    12        0        0           0
# 729      730  31-12-2019       1   1    12        0        1           1
#
#      weathersit       temp     atemp      hum  windspeed  casual  registered  \
# 0             2  14.110847  18.18125  80.5833  10.749882     331         654
# 1             2  14.902598  17.68695  69.6087  16.652113     131         670
# 2             1   8.050924   9.47025  43.7273  16.636703     120        1229
# 3             1   8.200000  10.60610  59.0435  10.739832     108        1454
# 4             1   9.305237  11.46350  43.6957  12.522300      82        1518
# ..          ...        ...       ...      ...        ...     ...         ...
# 725           2  10.420847  11.33210  65.2917  23.458911     247        1867
# 726           2  10.386653  12.75230  59.0000  10.416557     644        2451
# 727           2  10.386653  12.12000  75.2917   8.333661     159        1182
# 728           1  10.489153  11.58500  48.3333  23.500518     364        1432
# 729           2   8.849153  11.17435  57.7500  10.374682     439        2290
#
#       cnt
# 0     985
# 1     801
# 2    1349
# 3    1562
# 4    1600
# ..    ...
# 725  2114
# 726  3095
# 727  1341
# 728  1796
# 729  2729
#
# [730 rows x 16 columns]

# %%
dataset.shape
# Out:
# (730, 16)

# %%
dataset.columns
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'cnt'],
#       dtype='object')

# %%
dataset.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  01-01-2018       1   0     1        0        6           0
# 1        2  02-01-2018       1   0     1        0        0           0
# 2        3  03-01-2018       1   0     1        0        1           1
# 3        4  04-01-2018       1   0     1        0        2           1
# 4        5  05-01-2018       1   0     1        0        3           1
#
#    weathersit       temp     atemp      hum  windspeed  casual  registered  \
# 0           2  14.110847  18.18125  80.5833  10.749882     331         654
# 1           2  14.902598  17.68695  69.6087  16.652113     131         670
# 2           1   8.050924   9.47025  43.7273  16.636703     120        1229
# 3           1   8.200000  10.60610  59.0435  10.739832     108        1454
# 4           1   9.305237  11.46350  43.6957  12.522300      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
dataset.isnull()
# Out:
#      instant  dteday  season     yr   mnth  holiday  weekday  workingday  \
# 0      False   False   False  False  False    False    False       False
# 1      False   False   False  False  False    False    False       False
# 2      False   False   False  False  False    False    False       False
# 3      False   False   False  False  False    False    False       False
# 4      False   False   False  False  False    False    False       False
# ..       ...     ...     ...    ...    ...      ...      ...         ...
# 725    False   False   False  False  False    False    False       False
# 726    False   False   False  False  False    False    False       False
# 727    False   False   False  False  False    False    False       False
# 728    False   False   False  False  False    False    False       False
# 729    False   False   False  False  False    False    False       False
#
#      weathersit   temp  atemp    hum  windspeed  casual  registered    cnt
# 0         False  False  False  False      False   False       False  False
# 1         False  False  False  False      False   False       False  False
# 2         False  False  False  False      False   False       False  False
# 3         False  False  False  False      False   False       False  False
# 4         False  False  False  False      False   False       False  False
# ..          ...    ...    ...    ...        ...     ...         ...    ...
# 725       False  False  False  False      False   False       False  False
# 726       False  False  False  False      False   False       False  False
# 727       False  False  False  False      False   False       False  False
# 728       False  False  False  False      False   False       False  False
# 729       False  False  False  False      False   False       False  False
#
# [730 rows x 16 columns]

# %%
dataset.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     730 non-null    int64
#  1   dteday      730 non-null    object
#  2   season      730 non-null    int64
#  3   yr          730 non-null    int64
#  4   mnth        730 non-null    int64
#  5   holiday     730 non-null    int64
#  6   weekday     730 non-null    int64
#  7   workingday  730 non-null    int64
#  8   weathersit  730 non-null    int64
#  9   temp        730 non-null    float64
#  10  atemp       730 non-null    float64
#  11  hum         730 non-null    float64
#  12  windspeed   730 non-null    float64
#  13  casual      730 non-null    int64
#  14  registered  730 non-null    int64
#  15  cnt         730 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.4+ KB

# %%
dataset.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  730.000000  730.000000  730.000000  730.000000  730.000000  730.000000
# mean   365.500000    2.498630    0.500000    6.526027    0.028767    2.997260
# std    210.877136    1.110184    0.500343    3.450215    0.167266    2.006161
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.250000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    365.500000    3.000000    0.500000    7.000000    0.000000    3.000000
# 75%    547.750000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    730.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  730.000000  730.000000  730.000000  730.000000  730.000000  730.000000
# mean     0.683562    1.394521   20.319259   23.726322   62.765175   12.763620
# std      0.465405    0.544807    7.506729    8.150308   14.237589    5.195841
# min      0.000000    1.000000    2.424346    3.953480    0.000000    1.500244
# 25%      0.000000    1.000000   13.811885   16.889713   52.000000    9.041650
# 50%      1.000000    1.000000   20.465826   24.368225   62.625000   12.125325
# 75%      1.000000    2.000000   26.880615   30.445775   72.989575   15.625589
# max      1.000000    3.000000   35.328347   42.044800   97.250000   34.000021
#
#             casual   registered          cnt
# count   730.000000   730.000000   730.000000
# mean    849.249315  3658.757534  4508.006849
# std     686.479875  1559.758728  1936.011647
# min       2.000000    20.000000    22.000000
# 25%     316.250000  2502.250000  3169.750000
# 50%     717.000000  3664.500000  4548.500000
# 75%    1096.500000  4783.250000  5966.000000
# max    3410.000000  6946.000000  8714.000000

# %%
#assigning the seasons 
#Spring
dataset.loc[dataset["season"] == 1, "season"] = 'spring'
#Summer
dataset.loc[dataset["season"] == 2, "season"] = 'summer'
#fall
dataset.loc[dataset["season"] == 3, "season"] = 'fall'
#winter
dataset.loc[dataset["season"] == 4, "season"] = 'winter'
dataset
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_11992\4080586884.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'spring' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dataset.loc[dataset["season"] == 1, "season"] = 'spring'
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  01-01-2018  spring   0     1        0        6           0
# 1          2  02-01-2018  spring   0     1        0        0           0
# 2          3  03-01-2018  spring   0     1        0        1           1
# 3          4  04-01-2018  spring   0     1        0        2           1
# 4          5  05-01-2018  spring   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 725      726  27-12-2019  spring   1    12        0        4           1
# 726      727  28-12-2019  spring   1    12        0        5           1
# 727      728  29-12-2019  spring   1    12        0        6           0
# 728      729  30-12-2019  spring   1    12        0        0           0
# 729      730  31-12-2019  spring   1    12        0        1           1
#
#      weathersit       temp     atemp      hum  windspeed  casual  registered  \
# 0             2  14.110847  18.18125  80.5833  10.749882     331         654
# 1             2  14.902598  17.68695  69.6087  16.652113     131         670
# 2             1   8.050924   9.47025  43.7273  16.636703     120        1229
# 3             1   8.200000  10.60610  59.0435  10.739832     108        1454
# 4             1   9.305237  11.46350  43.6957  12.522300      82        1518
# ..          ...        ...       ...      ...        ...     ...         ...
# 725           2  10.420847  11.33210  65.2917  23.458911     247        1867
# 726           2  10.386653  12.75230  59.0000  10.416557     644        2451
# 727           2  10.386653  12.12000  75.2917   8.333661     159        1182
# 728           1  10.489153  11.58500  48.3333  23.500518     364        1432
# 729           2   8.849153  11.17435  57.7500  10.374682     439        2290
#
#       cnt
# 0     985
# 1     801
# 2    1349
# 3    1562
# 4    1600
# ..    ...
# 725  2114
# 726  3095
# 727  1341
# 728  1796
# 729  2729
#
# [730 rows x 16 columns]

# %%
dataset['season'].astype('category').value_counts()
# Out:
# season
# fall      188
# summer    184
# spring    180
# winter    178
# Name: count, dtype: int64

# %%
dataset['yr'].astype('category').value_counts()
# Out:
# yr
# 0    365
# 1    365
# Name: count, dtype: int64

# %%
def object_map_months(x):
    month_map = {1: 'Jan', 2: 'Feb', 3: 'Mar', 4: 'Apr', 5: 'May', 6: 'Jun', 7: 'Jul', 8: 'Aug', 9: 'Sep', 10: 'Oct', 11: 'Nov', 12: 'Dec'}
    return x.map(month_map)

# %%
dataset[['mnth']]=dataset[['mnth']].apply(object_map_months)

# %%
dataset[['mnth']].astype('category').value_counts()
# Out:
# mnth
# Aug     62
# Dec     62
# Jan     62
# Jul     62
# Mar     62
# May     62
# Oct     62
# Apr     60
# Jun     60
# Nov     60
# Sep     60
# Feb     56
# Name: count, dtype: int64

# %%
dataset['holiday'].astype('category').value_counts()
# Out:
# holiday
# 0    709
# 1     21
# Name: count, dtype: int64

# %%
def str_map_weekdays(x):
    return x.map({1: 'Sun', 2: 'Mon', 3: 'Tue', 4: 'Wed', 5: 'Thu', 6: 'Fri', 7: 'Sat'})

# %%
dataset[['weekday']] = dataset[['weekday']].apply(str_map_weekdays)

# %%
dataset[['weekday']].astype('category').value_counts()
# Out:
# weekday
# Fri        105
# Sun        105
# Mon        104
# Thu        104
# Wed        104
# Tue        103
# Name: count, dtype: int64

# %%
dataset[['workingday']].astype('category').value_counts()
# Out:
# workingday
# 1             499
# 0             231
# Name: count, dtype: int64

# %%
#clear
dataset.loc[dataset["weathersit"] == 1, "weathersit"] = 'A'
#partly clody
dataset.loc[dataset["weathersit"] == 2, "weathersit"] = 'B'
#heavy rain/snow
dataset.loc[dataset["weathersit"] == 3, "weathersit"] = 'C'
dataset
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_11992\1853302990.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'A' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dataset.loc[dataset["weathersit"] == 1, "weathersit"] = 'A'
#      instant      dteday  season  yr mnth  holiday weekday  workingday  \
# 0          1  01-01-2018  spring   0  Jan        0     Fri           0
# 1          2  02-01-2018  spring   0  Jan        0     NaN           0
# 2          3  03-01-2018  spring   0  Jan        0     Sun           1
# 3          4  04-01-2018  spring   0  Jan        0     Mon           1
# 4          5  05-01-2018  spring   0  Jan        0     Tue           1
# ..       ...         ...     ...  ..  ...      ...     ...         ...
# 725      726  27-12-2019  spring   1  Dec        0     Wed           1
# 726      727  28-12-2019  spring   1  Dec        0     Thu           1
# 727      728  29-12-2019  spring   1  Dec        0     Fri           0
# 728      729  30-12-2019  spring   1  Dec        0     NaN           0
# 729      730  31-12-2019  spring   1  Dec        0     Sun           1
#
#     weathersit       temp     atemp      hum  windspeed  casual  registered  \
# 0            B  14.110847  18.18125  80.5833  10.749882     331         654
# 1            B  14.902598  17.68695  69.6087  16.652113     131         670
# 2            A   8.050924   9.47025  43.7273  16.636703     120        1229
# 3            A   8.200000  10.60610  59.0435  10.739832     108        1454
# 4            A   9.305237  11.46350  43.6957  12.522300      82        1518
# ..         ...        ...       ...      ...        ...     ...         ...
# 725          B  10.420847  11.33210  65.2917  23.458911     247        1867
# 726          B  10.386653  12.75230  59.0000  10.416557     644        2451
# 727          B  10.386653  12.12000  75.2917   8.333661     159        1182
# 728          A  10.489153  11.58500  48.3333  23.500518     364        1432
# 729          B   8.849153  11.17435  57.7500  10.374682     439        2290
#
#       cnt
# 0     985
# 1     801
# 2    1349
# 3    1562
# 4    1600
# ..    ...
# 725  2114
# 726  3095
# 727  1341
# 728  1796
# 729  2729
#
# [730 rows x 16 columns]

# %%
dataset[['weathersit']].astype('category').value_counts()
# Out:
# weathersit
# A             463
# B             246
# C              21
# Name: count, dtype: int64

# %% [markdown]
# data visualisation

# %% [markdown]
#  2.data visualistion

# %%
sns.distplot(dataset['temp'])
plt.show
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_11992\3146156309.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['temp'])
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.distplot(dataset['atemp'])
plt.show
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_11992\2268482482.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['atemp'])
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
dataset['dteday'] = pd.to_datetime(dataset['dteday'], format='%d-%m-%Y')

# %%
dataset_categorical=dataset.select_dtypes(exclude=["float","datetime64" , "int64"])

# %%
dataset_categorical.columns
# Out:
# Index(['season', 'mnth', 'weekday', 'weathersit'], dtype='object')

# %%
dataset_categorical
# Out:
#      season mnth weekday weathersit
# 0    spring  Jan     Fri          B
# 1    spring  Jan     NaN          B
# 2    spring  Jan     Sun          A
# 3    spring  Jan     Mon          A
# 4    spring  Jan     Tue          A
# ..      ...  ...     ...        ...
# 725  spring  Dec     Wed          B
# 726  spring  Dec     Thu          B
# 727  spring  Dec     Fri          B
# 728  spring  Dec     NaN          A
# 729  spring  Dec     Sun          B
#
# [730 rows x 4 columns]

# %%
plt.figure(figsize=(20,30))
plt.subplot(3,3,1)
sns.boxplot(x="season", y="cnt",data=dataset)
plt.subplot(3,3,2)
sns.boxplot(x="mnth", y="cnt",data=dataset)
plt.subplot(3,3,3)
sns.boxplot(x="weekday", y="cnt",data=dataset)
plt.subplot(3,3,4)
sns.boxplot(x="weathersit", y="cnt",data=dataset)
plt.subplot(3,3,5)
sns.boxplot(x="workingday", y="cnt",data=dataset)
plt.subplot(3,3,6)
sns.boxplot(x="yr", y="cnt",data=dataset)
plt.subplot(3,3,7)
sns.boxplot(x="holiday", y="cnt",data=dataset)
# Out:
# <Axes: xlabel='holiday', ylabel='cnt'>

# %%
dataset_numeric = dataset.select_dtypes(include=("float64"))
dataset_numeric.head()
# Out:
#         temp     atemp      hum  windspeed
# 0  14.110847  18.18125  80.5833  10.749882
# 1  14.902598  17.68695  69.6087  16.652113
# 2   8.050924   9.47025  43.7273  16.636703
# 3   8.200000  10.60610  59.0435  10.739832
# 4   9.305237  11.46350  43.6957  12.522300

# %%
# Convert infinite values to NaN
dataset.replace([np.inf, -np.inf], np.nan, inplace=True)

# %%
intvarlist=["casual" , "registered" , "cnt"]
for var in intvarlist:
    dataset[var]=dataset[var].astype("float")

# %%
sns.pairplot(dataset_numeric)
plt.show
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
cor = dataset_numeric.corr()
cor
# Out:
#                temp     atemp       hum  windspeed
# temp       1.000000  0.991696  0.128565  -0.158186
# atemp      0.991696  1.000000  0.141512  -0.183876
# hum        0.128565  0.141512  1.000000  -0.248506
# windspeed -0.158186 -0.183876 -0.248506   1.000000

# %%
mask = np.array(cor)
mask[np.tril_indices_from(mask)] = False
fig, ax = plt.subplots()
fig.set_size_inches(10, 10)
sns.heatmap(cor, mask=mask, vmax=1, square=True, annot=True)
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)

# %%
dataset.drop('atemp',axis=1,inplace = True)

# %%
dataset
# Out:
#      instant     dteday  season  yr mnth  holiday weekday  workingday  \
# 0          1 2018-01-01  spring   0  Jan        0     Fri           0
# 1          2 2018-01-02  spring   0  Jan        0     NaN           0
# 2          3 2018-01-03  spring   0  Jan        0     Sun           1
# 3          4 2018-01-04  spring   0  Jan        0     Mon           1
# 4          5 2018-01-05  spring   0  Jan        0     Tue           1
# ..       ...        ...     ...  ..  ...      ...     ...         ...
# 725      726 2019-12-27  spring   1  Dec        0     Wed           1
# 726      727 2019-12-28  spring   1  Dec        0     Thu           1
# 727      728 2019-12-29  spring   1  Dec        0     Fri           0
# 728      729 2019-12-30  spring   1  Dec        0     NaN           0
# 729      730 2019-12-31  spring   1  Dec        0     Sun           1
#
#     weathersit       temp      hum  windspeed  casual  registered     cnt
# 0            B  14.110847  80.5833  10.749882   331.0       654.0   985.0
# 1            B  14.902598  69.6087  16.652113   131.0       670.0   801.0
# 2            A   8.050924  43.7273  16.636703   120.0      1229.0  1349.0
# 3            A   8.200000  59.0435  10.739832   108.0      1454.0  1562.0
# 4            A   9.305237  43.6957  12.522300    82.0      1518.0  1600.0
# ..         ...        ...      ...        ...     ...         ...     ...
# 725          B  10.420847  65.2917  23.458911   247.0      1867.0  2114.0
# 726          B  10.386653  59.0000  10.416557   644.0      2451.0  3095.0
# 727          B  10.386653  75.2917   8.333661   159.0      1182.0  1341.0
# 728          A  10.489153  48.3333  23.500518   364.0      1432.0  1796.0
# 729          B   8.849153  57.7500  10.374682   439.0      2290.0  2729.0
#
# [730 rows x 15 columns]

# %%
#data preparation begins

# %%
dataset_categorical = dataset.select_dtypes(include=['object'])

# %%
dataset_categorical.head()
# Out:
#    season mnth weekday weathersit
# 0  spring  Jan     Fri          B
# 1  spring  Jan     NaN          B
# 2  spring  Jan     Sun          A
# 3  spring  Jan     Mon          A
# 4  spring  Jan     Tue          A

# %%
dataset_dummies =pd.get_dummies(dataset_categorical,drop_first =True)
dataset_dummies.head()
# Out:
#    season_spring  season_summer  season_winter  mnth_Aug  mnth_Dec  mnth_Feb  \
# 0           True          False          False     False     False     False
# 1           True          False          False     False     False     False
# 2           True          False          False     False     False     False
# 3           True          False          False     False     False     False
# 4           True          False          False     False     False     False
#
#    mnth_Jan  mnth_Jul  mnth_Jun  mnth_Mar  ...  mnth_Nov  mnth_Oct  mnth_Sep  \
# 0      True     False     False     False  ...     False     False     False
# 1      True     False     False     False  ...     False     False     False
# 2      True     False     False     False  ...     False     False     False
# 3      True     False     False     False  ...     False     False     False
# 4      True     False     False     False  ...     False     False     False
#
#    weekday_Mon  weekday_Sun  weekday_Thu  weekday_Tue  weekday_Wed  \
# 0        False        False        False        False        False
# 1        False        False        False        False        False
# 2        False         True        False        False        False
# 3         True        False        False        False        False
# 4        False        False        False         True        False
#
#    weathersit_B  weathersit_C
# 0          True         False
# 1          True         False
# 2         False         False
# 3         False         False
# 4         False         False
#
# [5 rows x 21 columns]

# %%
dataset = dataset.drop(list(dataset_categorical.columns) , axis=1)
dataset
# Out:
#      instant     dteday  yr  holiday  workingday       temp      hum  \
# 0          1 2018-01-01   0        0           0  14.110847  80.5833
# 1          2 2018-01-02   0        0           0  14.902598  69.6087
# 2          3 2018-01-03   0        0           1   8.050924  43.7273
# 3          4 2018-01-04   0        0           1   8.200000  59.0435
# 4          5 2018-01-05   0        0           1   9.305237  43.6957
# ..       ...        ...  ..      ...         ...        ...      ...
# 725      726 2019-12-27   1        0           1  10.420847  65.2917
# 726      727 2019-12-28   1        0           1  10.386653  59.0000
# 727      728 2019-12-29   1        0           0  10.386653  75.2917
# 728      729 2019-12-30   1        0           0  10.489153  48.3333
# 729      730 2019-12-31   1        0           1   8.849153  57.7500
#
#      windspeed  casual  registered     cnt
# 0    10.749882   331.0       654.0   985.0
# 1    16.652113   131.0       670.0   801.0
# 2    16.636703   120.0      1229.0  1349.0
# 3    10.739832   108.0      1454.0  1562.0
# 4    12.522300    82.0      1518.0  1600.0
# ..         ...     ...         ...     ...
# 725  23.458911   247.0      1867.0  2114.0
# 726  10.416557   644.0      2451.0  3095.0
# 727   8.333661   159.0      1182.0  1341.0
# 728  23.500518   364.0      1432.0  1796.0
# 729  10.374682   439.0      2290.0  2729.0
#
# [730 rows x 11 columns]

# %%
dataset = dataset.drop(['instant','dteday'] , axis=1,inplace= False)

# %%
dataset.head()
# Out:
#    yr  holiday  workingday       temp      hum  windspeed  casual  registered  \
# 0   0        0           0  14.110847  80.5833  10.749882   331.0       654.0
# 1   0        0           0  14.902598  69.6087  16.652113   131.0       670.0
# 2   0        0           1   8.050924  43.7273  16.636703   120.0      1229.0
# 3   0        0           1   8.200000  59.0435  10.739832   108.0      1454.0
# 4   0        0           1   9.305237  43.6957  12.522300    82.0      1518.0
#
#       cnt
# 0   985.0
# 1   801.0
# 2  1349.0
# 3  1562.0
# 4  1600.0

# %%
#model building and evaluation

# %%
from sklearn import linear_model
from sklearn.linear_model import LinearRegression

# %%
from sklearn.model_selection import train_test_split
np.random .seed(0)
df_train,df_test = train_test_split(dataset,train_size=0.7 , test_size=0.3,random_state=100)

# %%
df_train
# Out:
#      yr  holiday  workingday       temp      hum  windspeed  casual  \
# 653   1        0           1  19.201653  55.8333  12.208807   922.0
# 576   1        0           1  29.246653  70.4167  11.083475   968.0
# 426   1        0           0  16.980847  62.1250  10.792293   956.0
# 728   1        0           0  10.489153  48.3333  23.500518   364.0
# 482   1        0           0  15.443347  48.9583   8.708325  1120.0
# ..   ..      ...         ...        ...      ...        ...     ...
# 526   1        0           1  29.554153  58.7917  13.916771  1017.0
# 578   1        0           1  30.852500  65.9583   8.666718   983.0
# 53    0        0           1   9.091299  42.3043   6.305571   139.0
# 350   0        0           0  10.591653  56.0833  16.292189   275.0
# 79    0        0           1  17.647835  73.7391  19.348461   401.0
#
#      registered     cnt
# 653      6612.0  7534.0
# 576      6248.0  7216.0
# 426      3110.0  4066.0
# 728      1432.0  1796.0
# 482      3100.0  4220.0
# ..          ...     ...
# 526      5647.0  6664.0
# 578      6278.0  7261.0
# 53       1778.0  1917.0
# 350      2464.0  2739.0
# 79       1676.0  2077.0
#
# [510 rows x 9 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()

# %%
var=["temp", "hum" , "windspeed" , "casual" , "registered" ,"cnt"]
df_train[var] = scaler.fit_transform(df_train[var])

# %%
df_train.describe()
# Out:
#                yr     holiday  workingday        temp         hum   windspeed  \
# count  510.000000  510.000000  510.000000  510.000000  510.000000  510.000000
# mean     0.507843    0.025490    0.676471    0.537262    0.650369    0.320768
# std      0.500429    0.157763    0.468282    0.225844    0.145882    0.169797
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.339853    0.538643    0.199179
# 50%      1.000000    0.000000    1.000000    0.540519    0.653714    0.296763
# 75%      1.000000    0.000000    1.000000    0.735215    0.754830    0.414447
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#            casual  registered         cnt
# count  510.000000  510.000000  510.000000
# mean     0.254661    0.523944    0.513620
# std      0.206011    0.228175    0.224593
# min      0.000000    0.000000    0.000000
# 25%      0.094179    0.353487    0.356420
# 50%      0.212740    0.525123    0.518638
# 75%      0.327415    0.696073    0.684710
# max      1.000000    1.000000    1.000000

# %%
plt.figure(figsize=(30,30))
sns.heatmap(df_train.corr() ,annot=True,cmap="YlGnBu")
plt.show()

# %%
y_train = df_train.pop('cnt')
x_train= df_train.drop(['casual','registered'], axis=1)

# %%
x_train.head()
# Out:
#      yr  holiday  workingday      temp       hum  windspeed
# 653   1        0           1  0.509887  0.575354   0.300794
# 576   1        0           1  0.815169  0.725633   0.264686
# 426   1        0           0  0.442393  0.640189   0.255342
# 728   1        0           0  0.245101  0.498067   0.663106
# 482   1        0           0  0.395666  0.504508   0.188475

# %%
np.asarray(df_train)
# Out:
# array([[1.        , 0.        , 1.        , ..., 0.30079362, 0.28040232,
#         0.95177592],
#        [1.        , 0.        , 1.        , ..., 0.26468552, 0.29442243,
#         0.89922033],
#        [1.        , 0.        , 0.        , ..., 0.25534248, 0.29076501,
#         0.44614496],
#        ...,
#        [0.        , 0.        , 1.        , ..., 0.11137874, 0.04175556,
#         0.25382616],
#        [0.        , 0.        , 0.        , ..., 0.43181554, 0.08320634,
#         0.35287323],
#        [0.        , 0.        , 1.        , ..., 0.52988098, 0.12160927,
#         0.23909905]])

# %%
import statsmodels.api as sm
x_train_lm = sm.add_constant(x_train)
lr=sm.OLS(y_train,x_train_lm).fit()

# %%
x_train_lm
# Out:
#      const  yr  holiday  workingday      temp       hum  windspeed
# 653    1.0   1        0           1  0.509887  0.575354   0.300794
# 576    1.0   1        0           1  0.815169  0.725633   0.264686
# 426    1.0   1        0           0  0.442393  0.640189   0.255342
# 728    1.0   1        0           0  0.245101  0.498067   0.663106
# 482    1.0   1        0           0  0.395666  0.504508   0.188475
# ..     ...  ..      ...         ...       ...       ...        ...
# 526    1.0   1        0           1  0.824514  0.605840   0.355596
# 578    1.0   1        0           1  0.863973  0.679690   0.187140
# 53     1.0   0        0           1  0.202618  0.435939   0.111379
# 350    1.0   0        0           0  0.248216  0.577930   0.431816
# 79     1.0   0        0           1  0.462664  0.759870   0.529881
#
# [510 rows x 7 columns]

# %%
lr.params
# Out:
# const         0.320291
# yr            0.231155
# holiday      -0.065641
# workingday    0.011173
# temp          0.570023
# hum          -0.241885
# windspeed    -0.245925
# dtype: float64

# %%
lm=LinearRegression()
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print (lm.coef_)
print(lm.intercept_)
# Out:
# [ 0.23115477 -0.06564118  0.01117328  0.5700234  -0.24188517 -0.24592469]
# 0.32029138651348876

# %%
lr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.737
# Model:                            OLS   Adj. R-squared:                  0.734
# Method:                 Least Squares   F-statistic:                     234.6
# Date:                Sun, 31 Mar 2024   Prob (F-statistic):          3.03e-142
# Time:                        19:51:37   Log-Likelihood:                 378.81
# No. Observations:                 510   AIC:                            -743.6
# Df Residuals:                     503   BIC:                            -714.0
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.3203      0.032      9.905      0.000       0.257       0.384
# yr             0.2312      0.010     22.254      0.000       0.211       0.252
# holiday       -0.0656      0.034     -1.957      0.051      -0.132       0.000
# workingday     0.0112      0.011      0.988      0.324      -0.011       0.033
# temp           0.5700      0.024     24.214      0.000       0.524       0.616
# hum           -0.2419      0.037     -6.541      0.000      -0.315      -0.169
# windspeed     -0.2459      0.032     -7.736      0.000      -0.308      -0.183
# ==============================================================================
# Omnibus:                       15.562   Durbin-Watson:                   2.032
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               18.335
# Skew:                          -0.336   Prob(JB):                     0.000104
# Kurtosis:                       3.641   Cond. No.                         15.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
from sklearn.feature_selection import RFE

# %%
#lm=LinearRegression()
#rfe1 = RFE(lm,15) 
#rfe1.fit(x_train, y_train)
#print(rfe1.support_)
#print(rfe1.ranking_)
#from sklearn.feature_selection import RFE

# Assuming lm is your LinearRegression model and 15 is the number of features to select
rfe1 = RFE(estimator=lm, n_features_to_select=15)
rfe1.fit(x_train, y_train)
print(rfe1.support_)
print(rfe1.ranking_)
# Out:
# [ True  True  True  True  True  True]
# [1 1 1 1 1 1]

# %%
coll = x_train.columns[rfe1.support_]

# %%
coll
# Out:
# Index(['yr', 'holiday', 'workingday', 'temp', 'hum', 'windspeed'], dtype='object')

# %%
x_train_rfe1 = x_train[coll]
x_train_rfe1 = sm.add_constant(x_train_rfe1)
lm1 = sm.OLS(y_train, x_train_rfe1).fit()
lm1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.737
# Model:                            OLS   Adj. R-squared:                  0.734
# Method:                 Least Squares   F-statistic:                     234.6
# Date:                Sun, 31 Mar 2024   Prob (F-statistic):          3.03e-142
# Time:                        19:51:38   Log-Likelihood:                 378.81
# No. Observations:                 510   AIC:                            -743.6
# Df Residuals:                     503   BIC:                            -714.0
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.3203      0.032      9.905      0.000       0.257       0.384
# yr             0.2312      0.010     22.254      0.000       0.211       0.252
# holiday       -0.0656      0.034     -1.957      0.051      -0.132       0.000
# workingday     0.0112      0.011      0.988      0.324      -0.011       0.033
# temp           0.5700      0.024     24.214      0.000       0.524       0.616
# hum           -0.2419      0.037     -6.541      0.000      -0.315      -0.169
# windspeed     -0.2459      0.032     -7.736      0.000      -0.308      -0.183
# ==============================================================================
# Omnibus:                       15.562   Durbin-Watson:                   2.032
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               18.335
# Skew:                          -0.336   Prob(JB):                     0.000104
# Kurtosis:                       3.641   Cond. No.                         15.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
a= x_train_rfe1.drop('const',axis=1)

# %%
vif = pd.DataFrame()
vif['features']= a.columns
vif['VIF'] = [variance_inflation_factor(a.values , i)for i in range (a.shape[1])]
vif['VIF'] = round(vif['VIF'],2)
vif = vif.sort_values(by = 'VIF',ascending = False)
vif
# Out:
#      features   VIF
# 4         hum  8.75
# 3        temp  6.40
# 5   windspeed  3.45
# 2  workingday  3.12
# 0          yr  2.01
# 1     holiday  1.07

# %%
lm = LinearRegression()  # Assuming lm is your LinearRegression model
rfe2 = RFE(estimator=lm, n_features_to_select=7)
rfe2.fit(x_train, y_train)
print(rfe2.support_)
print(rfe2.ranking_)
# Out:
# [ True  True  True  True  True  True]
# [1 1 1 1 1 1]

# %%
coll2 = x_train.columns[rfe2.support_]

x_train_rfe2 = x_train[coll2]
x_train_rfe2 = sm.add_constant(x_train_rfe2)
lm2 = sm.OLS(y_train, x_train_rfe2).fit()
lm2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.737
# Model:                            OLS   Adj. R-squared:                  0.734
# Method:                 Least Squares   F-statistic:                     234.6
# Date:                Sun, 31 Mar 2024   Prob (F-statistic):          3.03e-142
# Time:                        19:51:38   Log-Likelihood:                 378.81
# No. Observations:                 510   AIC:                            -743.6
# Df Residuals:                     503   BIC:                            -714.0
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.3203      0.032      9.905      0.000       0.257       0.384
# yr             0.2312      0.010     22.254      0.000       0.211       0.252
# holiday       -0.0656      0.034     -1.957      0.051      -0.132       0.000
# workingday     0.0112      0.011      0.988      0.324      -0.011       0.033
# temp           0.5700      0.024     24.214      0.000       0.524       0.616
# hum           -0.2419      0.037     -6.541      0.000      -0.315      -0.169
# windspeed     -0.2459      0.032     -7.736      0.000      -0.308      -0.183
# ==============================================================================
# Omnibus:                       15.562   Durbin-Watson:                   2.032
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               18.335
# Skew:                          -0.336   Prob(JB):                     0.000104
# Kurtosis:                       3.641   Cond. No.                         15.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
y_train_cnt = lm2.predict(x_train_rfe2)

# %%
# Plot the distribution
fig = plt.figure()
sns.distplot((y_train, y_train_cnt),bins =20)
plt.show()
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_11992\2827774315.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot((y_train, y_train_cnt),bins =20)
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
df_test[var] =  scaler.transform(df_test[var])
df_test
# Out:
#      yr  holiday  workingday      temp       hum  windspeed    casual  \
# 184   0        1           0  0.831783  0.657364   0.084219  0.933557
# 535   1        0           1  0.901354  0.610133   0.153728  0.265163
# 299   0        0           1  0.511964  0.837699   0.334206  0.072539
# 221   0        0           1  0.881625  0.437098   0.339570  0.268820
# 152   0        0           1  0.817246  0.314298   0.537414  0.223712
# ..   ..      ...         ...       ...       ...        ...       ...
# 400   1        0           0  0.257562  0.708888   0.287411  0.096312
# 702   1        0           1  0.519232  0.756118   0.283397  0.167327
# 127   0        0           0  0.584649  0.650923   0.069510  0.426394
# 640   1        0           1  0.745598  0.817947   0.052115  0.221274
# 72    0        0           1  0.331557  0.512107   0.203418  0.108808
#
#      registered       cnt
# 184    0.427086  0.692706
# 535    0.767976  0.712034
# 299    0.346376  0.303382
# 221    0.559630  0.547400
# 152    0.608143  0.569029
# ..          ...       ...
# 400    0.376697  0.336516
# 702    0.871354  0.757478
# 127    0.420445  0.495973
# 640    0.985273  0.868615
# 72     0.240687  0.232858
#
# [219 rows x 9 columns]

# %%
y_test = df_test.pop('cnt')
x_test = df_test.drop(["casual", "registered"] , axis= 1)

# %%
x_test.head()
# Out:
#      yr  holiday  workingday      temp       hum  windspeed
# 184   0        1           0  0.831783  0.657364   0.084219
# 535   1        0           1  0.901354  0.610133   0.153728
# 299   0        0           1  0.511964  0.837699   0.334206
# 221   0        0           1  0.881625  0.437098   0.339570
# 152   0        0           1  0.817246  0.314298   0.537414

# %%
c = x_train_rfe2.drop('const', axis= 1)

# %%
col2= c.columns

# %%
x_test_rfe2 = x_test[col2]

# %%
x_test_rfe2 = sm.add_constant(x_test_rfe2)

# %%
x_test_rfe2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 219 entries, 184 to 72
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   const       219 non-null    float64
#  1   yr          219 non-null    int64
#  2   holiday     219 non-null    int64
#  3   workingday  219 non-null    int64
#  4   temp        219 non-null    float64
#  5   hum         219 non-null    float64
#  6   windspeed   219 non-null    float64
# dtypes: float64(4), int64(3)
# memory usage: 13.7 KB

# %%
y_pred = lm2.predict(x_test_rfe2)

# %%
plt.figure()
plt.scatter(y_test,y_pred)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.7122126941120651

# %%
plt.figure(figsize=(8,5))
sns.heatmap(dataset[col2].corr(), cmap="YlGnBu" , annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # Thank You
